# %%
# !pip install pyDOE
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pyDOE) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from pyDOE) (1.10.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18184 sha256=eed27beeac0827106e8f85c43c1d3c64a673afd7b034d8f96ce67b65d20966a5
#   Stored in directory: /root/.cache/pip/wheels/3c/ca/0d/63b767ad585fbcb3ea222541572dcb78859d0383510672b105
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt

import imageio
import os
from google.colab import files

# %%
# For reproducability
tf.random.set_seed(1234)
np.random.seed(1234)

# %%
u0 = lambda x, k, p: np.cos(k*np.pi*x + p)
c = -0.0025

# %%
# Boundaries of the computational domain
xleft, xright = -1, 1
t0, tfinal = 0, 1.0

# %%
# Plot initial solution
k, p = 2, 0.1

x = np.linspace(xleft, xright, 100)
plt.plot(x, u0(x, k, p))
plt.grid()
plt.xlabel('x')
plt.ylabel('u')
# Out:
# Text(0, 0.5, 'u')

# %% [markdown]
# ### Define the network

# %%
# Define the network
def build_neural_network(n_layers = 6, n_units = 20, summary = False):

  inp1 = tf.keras.layers.Input(shape=(1,))
  b1 = tf.keras.layers.Lambda(lambda x: 2.0*(x - xleft)/(xright-xleft)-1.0)(inp1)
  
  # Make input periodic
  inp2 = tf.keras.layers.Input(shape=(1,))
  b2 = tf.keras.layers.Lambda(lambda x: tf.concat((tf.cos(np.pi*x), 
                                                   tf.sin(np.pi*x)), axis=1))(inp2)
  
  b = tf.keras.layers.Concatenate()([b1, b2])

  for i in range(n_layers):
    b = tf.keras.layers.Dense(n_units, activation='tanh')(b)
  out = tf.keras.layers.Dense(1, activation='linear')(b)

  model = tf.keras.models.Model([inp1, inp2], out)

  if summary:
    model.summary()

  return model

# %% [markdown]
# ### Common functions

# %%
# Generate the collocation points for the PINN model
def generate_dataset(data, N_pde, N_iv, bs_pdes, bs_inits, k=1, p=0):

  # Extract the parameters of the model
  t_bdry = data['t_bdry']
  x_bdry = data['x_bdry']
  u0 = data['u0']

  # Sample points where to evaluate the PDE
  tx_min = np.array([t_bdry[0], x_bdry[0]])
  tx_max = np.array([t_bdry[1], x_bdry[1]])  
  pde_points = tx_min + (tx_max - tx_min)*lhs(2, N_pde)
  t_pde = pde_points[:,0]
  x_pde = pde_points[:,1]
  pdes = np.column_stack([t_pde, x_pde]).astype(np.float32)

  # Sample points where to evaluate the initial values
  init_points = tx_min[1:] + (tx_max[1:] - tx_min[1:])*lhs(1, N_iv)
  x_init = init_points
  t_init = t_bdry[0]+ 0.0*x_init
  u_init = u0(x_init, k, p)
  inits = np.column_stack([t_init, x_init, u_init]).astype(np.float32)

  ds_pde = tf.data.Dataset.from_tensor_slices(pdes)
  ds_pde = ds_pde.cache().shuffle(N_pde).batch(bs_pdes)

  ds_init = tf.data.Dataset.from_tensor_slices(inits)
  ds_init = ds_init.cache().shuffle(N_iv).batch(bs_inits)

  ds = tf.data.Dataset.zip((ds_pde, ds_init))
  ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

  return ds

# %%
# Convert the ragged tensors that make up a model into a one-dimensional vector
def reshape_to_vector(vars):
  vars_vector = tf.concat([tf.reshape(p, [-1]) for p in vars], axis=0)
  return vars_vector

# %%
# This updates the weights of a given model as ragged tensor from the weights
# collected in a one-dimensional weight vector
def reshape_to_model(vars, model):
    
  k = 0

  for (i, curr_layer) in enumerate(model.layers):
    weights_and_biases = curr_layer.get_weights()

    # Check if the layer actually has weights and then set them
    if len(weights_and_biases) > 1:
      new_weights_and_biases = []
      for l in range(len(weights_and_biases)):
        shape_weights = tf.shape(weights_and_biases[l])
        no_weights = tf.reduce_prod(shape_weights)
        new_weights_and_biases.append(tf.reshape(vars[k:k+no_weights], shape_weights))
        k += no_weights 

      # Now set the new weights  
      model.layers[i].set_weights(new_weights_and_biases)

# %%
def standardize_tensor(vars, ep = 1e-5):
  return vars/tf.sqrt(tf.reduce_mean(tf.square(vars) + ep, axis=0))

# %%
@tf.function
def train_step(pdes, inits, model, c=-0.0025):

  t_pde, x_pde = pdes[:,:1], pdes[:,1:2]
  t_init, x_init, u_init = inits[:,:1], inits[:,1:2], inits[:,2:3]

  # Outer gradient for tuning network parameters
  with tf.GradientTape() as tape:

    # Inner gradient for derivatives of u wrt x and t
    with tf.GradientTape() as tape1:
      tape1.watch(t_pde), tape1.watch(x_pde)
      with tf.GradientTape() as tape2:
        tape2.watch(t_pde), tape2.watch(x_pde)
        with tf.GradientTape() as tape3:
          tape3.watch(t_pde), tape3.watch(x_pde)
          u = model([t_pde, x_pde])
        [ut, ux] = tape3.gradient(u, [t_pde, x_pde])  
      uxx = tape2.gradient(ux, x_pde)
    uxxx = tape1.gradient(uxx, x_pde)

    # Solve the KdV equations
    eqn = ut+u*ux-c*uxxx

    # Define the PDE loss  
    PDEloss = tf.reduce_mean(tf.square(eqn))

    # Define the initial value loss
    u_init_pred = model([t_init, x_init])      
    IVloss = tf.reduce_mean(tf.square(u_init-u_init_pred))

    # Global loss
    loss = PDEloss + IVloss

  # Compute the gradient of the global loss wrt the model parameters
  grads = tape.gradient(loss, model.trainable_variables)

  return PDEloss, IVloss, grads

# %% [markdown]
# ### Adam optimizer

# %%
class AdamOptimizer():
  def __init__(self, learning_rate=5e-4, beta_1=0.9, beta_2=0.999, ep=1e-5):

    self.learning_rate = learning_rate
    self.beta_1 = beta_1
    self.beta_2 = beta_2
    self.ep = ep

    self.built = False
    self.steps = 0


  # Standard Adam
  def apply_gradients(self, vars, grads):

    # Reshape the weights and gradients into a vector
    vars_vector = reshape_to_vector(vars)
    grads_vector = reshape_to_vector(grads)

    # Add the momentum and velocity vectors
    if not self.built:

      self.momentum = tf.zeros(tf.shape(vars_vector))
      self.velocity = tf.zeros(tf.shape(vars_vector))
      self.built = True

    # Update step counter
    self.steps += 1

    # Adam update rule
    self.momentum = self.beta_1*self.momentum + (1-self.beta_1)*grads_vector
    self.velocity = self.beta_2*self.velocity + (1-self.beta_2)*tf.square(grads_vector)

    momentum_corr = self.momentum/(1-self.beta_1**self.steps) 
    velocity_corr = self.velocity/(1-self.beta_2**self.steps) 

    # Blackbox update
    adam_update = self.learning_rate*momentum_corr/tf.sqrt(velocity_corr + self.ep)
    
    # Update the weights
    vars_vector -= adam_update

    return vars_vector


  # Train a model using our Adam optimizer
  def train_model(self, data, model, epochs=5000, N_pde=10000, N_iv=100, 
                  k=1, p=0):

    # Generate the training dataset
    ds = generate_dataset(data, N_pde, N_iv, N_pde//10, N_iv//10, k, p)
  
    # Epoch loss initialization
    epoch_loss = np.zeros(epochs)

    # Main training loop
    for i in range(epochs):

      n_batches = 0
      for (pdes, inits) in ds:

        # Gradient step    
        PDEloss, IVloss, grads = train_step(pdes, inits, model)
        weights_updated = self.apply_gradients(model.trainable_variables, grads)
                                                         
        # Update the current model's weights
        reshape_to_model(weights_updated, model)

        # Accumulate the loss
        epoch_loss[i] += PDEloss + IVloss
        n_batches += 1

      epoch_loss[i] /= n_batches
      n_batches = 0

      if (np.mod(i, 100)==0):
        print(f"PDE loss, IV loss in {i}th epoch: {PDEloss.numpy():6.4f}, {IVloss.numpy():6.4f}")
      
    return epoch_loss

# %% [markdown]
# ### Learnable optimizer

# %%
class LearnableOptimizer():
  def __init__(self, learning_rate=5e-4, beta_1=0.9, beta_2=0.999, 
               m_decay = [0.5, 0.9, 0.99, 0.999], 
               v_decay = [0.5, 0.9, 0.99, 0.999],
               ep=1e-5, use_v_moment = True):

    # For the Adam part
    self.learning_rate = learning_rate
    self.beta_1 = beta_1
    self.beta_2 = beta_2
    self.ep = ep

    # For the learnable part
    self.m_decay = m_decay
    self.v_decay = v_decay    
    self.use_v_moment = use_v_moment

    self.no_m = len(m_decay)
    self.no_v = len(v_decay)

    if self.no_m != self.no_v:
      raise ValueError('Number of second moment decay value needs to equal number of first moment decay values.')

    self.built = False

    # Scaling of learnable parameters
    self.lambda1 = learning_rate
    self.lambda2 = 0.001 
    self.lambda3 = 0.001

    # Build a learnable optimizer
    self.optimizer = self.build_optimizer_model()


  def build_optimizer_model(self, summary = False):
    step_vector = [1, 3, 10, 30, 100, 300, 1000, 3000, 10000, 30000, 100000]

    # Build learnable optimizer MLP

    # Used for all optimizers:
    inp_w = tf.keras.layers.Input(shape=(1,))
    inp_g = tf.keras.layers.Input(shape=(1,))
    inp_m = tf.keras.layers.Input(shape=(self.no_m,))

    # If using the second momentum as well:
    if self.use_v_moment:
      inp_v = tf.keras.layers.Input(shape=(self.no_v,))
      inp_rv = tf.keras.layers.Input(shape=(self.no_v,))
      inp_corrected = tf.keras.layers.Input(shape=(self.no_v,))
    else:
      inp_v = tf.keras.layers.Input(shape=(1,))

    inp_timestep = tf.keras.layers.Input(shape=(1,))

    # Generate time embedding
    time_embedding = tf.keras.layers.Lambda(lambda t: [tf.math.tanh(t/x) for x in step_vector])(inp_timestep)

    # Concatenate and standardize the input features
    if self.use_v_moment:
      b = tf.keras.layers.Concatenate()([inp_w, inp_g, inp_m, inp_v, inp_rv, 
                                         inp_corrected])
      b = tf.keras.layers.Lambda(standardize_tensor)(b)
      b = tf.keras.layers.Concatenate()([b, *time_embedding])
    else:
      b = tf.keras.layers.Concatenate()([inp_w, inp_g, inp_m, inp_v])
      b = tf.keras.layers.Lambda(standardize_tensor)(b)
      b = tf.keras.layers.Concatenate()([b, *time_embedding])

    # A simple MLP network
    for i in range(2):
      b = tf.keras.layers.Dense(32, activation='swish')(b)
    
    # Initializer for the weight matrix (to produce close to zero initially)
    initializer = tf.keras.initializers.RandomNormal(0.0, 1e-3, seed=1234)

    out_mag = tf.keras.layers.Dense(1, kernel_initializer=initializer)(b)
    out_dir = tf.keras.layers.Dense(1, kernel_initializer=initializer)(b)
    out_nom = tf.keras.layers.Dense(1, kernel_initializer=initializer)(b)


    if self.use_v_moment:
      optModel = tf.keras.models.Model([inp_w, inp_g, inp_m, inp_v, inp_rv,
                                        inp_corrected, inp_timestep],
                                       [out_mag, out_dir, out_nom])
    else:
      optModel = tf.keras.models.Model([inp_w, inp_g, inp_m, inp_v, inp_timestep],
                                       [out_mag, out_dir, out_nom])
    if summary:
      optModel.summary()

    return optModel


  # This is the learnable optimizer
  def apply_gradients(self, vars, grads, optimizerModel):

    # Reshape the weights and gradients into a vector
    vars_vector = reshape_to_vector(vars)
    grads_vector = reshape_to_vector(grads)

    # Add the momentum and velocity vectors
    if not self.built:

      # Reset the step counter
      self.steps = 0

      # Initialize momenta and second momenta
      self.m = tf.zeros(tf.shape(vars_vector))
      self.v = tf.zeros(tf.shape(vars_vector))

      self.ms = []
      self.vs = []

      for i in range(self.no_m):
        self.ms.append(tf.zeros(tf.shape(vars_vector)))
        
        # Second momenta update
        if self.use_v_moment:
          self.vs.append(tf.zeros(tf.shape(vars_vector)))

      self.built = True

    # ----- This is the Adam update -----

    # Update step counter
    self.steps += 1

    # Adam update rule
    self.m = self.beta_1*self.m + (1-self.beta_1)*grads_vector
    self.v = self.beta_2*self.v + (1-self.beta_2)*tf.square(grads_vector)

    m_corr = self.m/(1-self.beta_1**self.steps) 
    v_corr = self.v/(1-self.beta_2**self.steps) 

    adam_update = self.learning_rate*m_corr/tf.sqrt(v_corr + self.ep)

    # ----- This is the Learnable part -----

    if self.use_v_moment:
      self.vhs = []
      self.rsqrtvs = []

    # Store the current AggMo momenta
    for i in range(self.no_m):
      
      # Momentum with respective decay rate
      self.ms[i] = self.m_decay[i]*self.ms[i] + (1-self.m_decay[i])*grads_vector

      if self.use_v_moment:
        self.vs[i] = self.v_decay[i]*self.vs[i] + (1-self.v_decay[i])*tf.square(grads_vector)
        self.vhs.append(self.ms[i]/tf.sqrt(self.vs[i] + self.ep))
        self.rsqrtvs.append(1./tf.sqrt(self.vs[i] + self.ep))
        
    # Reshape all the input features    
    weights = tf.expand_dims(vars_vector, axis=1)
    gradients = tf.expand_dims(grads_vector, axis=1)
    m = tf.transpose(tf.convert_to_tensor(self.ms), [1,0])
    
    if self.use_v_moment:
      v = tf.transpose(tf.convert_to_tensor(self.vs), [1,0])
      vh = tf.transpose(tf.convert_to_tensor(self.vhs), [1,0])
      rsqrtv = tf.transpose(tf.convert_to_tensor(self.rsqrtvs), [1,0])
    else:
      v = tf.expand_dims(self.v, axis=1)

    steps = tf.expand_dims(self.steps + 0*vars_vector, axis=1)

    # Predict magnitude, precondition and direction of update step
    if self.use_v_moment:
      [mag, dir, mag_nom] = optimizerModel([weights, gradients, m, v, rsqrtv, 
                                            vh, steps])    
    else:
      [mag, dir, mag_nom] = optimizerModel([weights, gradients, m, v, steps])
    
    # Blackbox update
    bb_update = self.lambda1*dir*tf.exp(self.lambda2*mag)/tf.sqrt(v[:,-1] + self.ep)

    # Scaled Adam update
    adam_scaled = tf.exp(self.lambda3*mag_nom[:,0])*adam_update

    # ---- Combined update -----

    # Update is the sum of Adam and learned update
    vars_vector -= (adam_scaled + bb_update[:,0])

    return vars_vector


  # Persistent evolution strategy for training the learnable optimizer
  def train_optimizer(self, data, model, N_pde = 10000, N_iv = 100, tasks = 5,
                      cycles = 5, steps = 100, K = 1, N = 2, sigma = 0.1, 
                      alpha = 1e-3, wd = 0.0, clipping = True, use_adam = False):

    # Shape of the optimizer weights as weight vector
    opt_shape = tf.shape(reshape_to_vector(self.optimizer.trainable_variables))

    # If using Adam for training, initialize first and second momentum
    if use_adam:
      opt_m = tf.zeros(shape = opt_shape)
      opt_v = tf.zeros(shape = opt_shape)

    # Main task loss
    task_loss = []

    self.steps = 0

    # Generate training datasets
    ds, c = [], []
    for task in range(tasks):
      
      # Sample a random IC
      k = np.random.randint(1, 4)
      p = np.random.uniform(-np.pi/2, np.pi/2)

      ds.append(generate_dataset(data, N_pde, N_iv, N_pde//10, N_iv//10, k, p))
      c.append(-0.0025)

    for cycle in range(cycles):

      print(f'Working on cycle {cycle+1} out of {cycles} cycles:')

      # Main task training loop
      for task in range(tasks):

        print(f'Working on task {task+1} out of {tasks} tasks:')

        # Reset the optimizer
        self.built = False

        # Convert optimizer ragged tensor to vector
        opt_vars = reshape_to_vector(self.optimizer.trainable_variables)

        # Initialize perturbed optimizers and their model copies
        models = []
        optimizers = []
        for i in range(N):
          models.append(build_neural_network())
          optimizers.append(self.build_optimizer_model())
          xi = np.zeros(shape = (N, opt_shape[0]), dtype=np.float64)

        # Mean loss over l-th step
        mean_losses = []

        # Run the optimization a total of steps time steps
        for l in range(steps):

          # Initialize the gradient vector
          gradient_pes = tf.zeros(shape = opt_shape)

          # Loss accumulator for N models
          all_losses = []

          print(f'Working on optimization step {l+1} out of {steps} steps:')

          # Train N particles
          for i in range(N):

            print(f'Training model {i+1} out of {N} models.')

            optimizers[i].set_weights(self.optimizer.get_weights())
            optimizer_i_vars = reshape_to_vector(optimizers[i].trainable_variables)

            # Perturbations
            if tf.math.mod(i+1, 2)==0:
              eps = -eps
            else:
              eps = tf.random.normal(shape = opt_shape, stddev=sigma**2)

            # Adjust weights of the temporary optimizer using the perturbations
            optimizer_i_vars += eps

            # Write these weights into the optimizer
            reshape_to_model(optimizer_i_vars, optimizers[i])

            # ---- Unroll the model ----
            losses = np.zeros(K)
            for k in range(K):
              
              # Mini-batch gradient descent
              no_batches = 0

              for (pdes, inits) in ds[task]:

                # Train the model for one batch (using the linear advection equation!)
                PDEloss, IVloss, grads = train_step(pdes, inits, models[i], c[task])
                temp_loss = PDEloss + IVloss

                # Gradient descent step with current perturbed learnable optimizer
                weights_updated = self.apply_gradients(models[i].trainable_variables, 
                                                      grads, optimizers[i])
                
                # Update the current model's weights
                reshape_to_model(weights_updated, models[i])

                # Check if model failed to train
                if tf.math.is_nan(temp_loss):
                  raise ValueError("Loss became NaN.")

                # Update the loss
                losses[k] += temp_loss
                no_batches += 1
              losses[k] /= no_batches

            # Update the perturbation vector
            xi[i,] += eps

            # Update the gradient vector
            gradient_pes += tf.cast(xi[i,]*tf.reduce_sum(losses), tf.float32)

            # Store loss values for i-th model
            all_losses.append(tf.reduce_mean(losses))

          print(f'Accumulated loss over step {l+1}: {tf.reduce_mean(all_losses): 6.4f}.\n')

          # Append the mean loss
          mean_losses.append(tf.reduce_mean(all_losses))

          # Correct the scaling to get the true gradient
          gradient_pes /= (N*sigma**2) 
          
          # Apply gradient clipping to norm 1
          if clipping:
            gradient_pes = tf.clip_by_norm(gradient_pes, clip_norm=1)

          # Update the optimizer weights using AdamW
          if use_adam:

            opt_m = self.beta_1*opt_m + (1-self.beta_1)*gradient_pes
            opt_v = self.beta_2*opt_v + (1-self.beta_2)*tf.square(gradient_pes)

            opt_m_corr = opt_m/(1-self.beta_1**(l+1))
            opt_v_corr = opt_v/(1-self.beta_2**(l+1))

            # AdamW update formula
            opt_vars -= alpha*(opt_m_corr/tf.sqrt(opt_v_corr + self.ep) + 
                              wd*opt_vars)
            
          # Standard SGD with weight decay
          else:

            opt_vars -= alpha*(gradient_pes + wd*opt_vars)

          # Update the optimizer
          reshape_to_model(opt_vars, self.optimizer)

        task_loss.append(mean_losses)

    print('Training done!')

    return np.array(task_loss)

  # ------------------------------------------------------------------
  # ------------------------------------------------------------------

  def train_model(self, data, model, epochs=5000, N_pde=10000, N_iv=100, k=1,
                  p=0):

    # Reset the optimizer
    self.built = False

    # Training dataset
    ds = generate_dataset(data, N_pde, N_iv, N_pde//10, N_iv//10, k, p)
  
    # Epoch loss initialization
    epoch_loss = np.zeros(epochs)

    # Main training loop
    for i in range(epochs):

      n_batches = 0
      for (pdes, inits) in ds:

        # Gradient step    
        PDEloss, IVloss, grads = train_step(pdes, inits, model)
        weights_updated = self.apply_gradients(model.trainable_variables, grads,
                                               self.optimizer)
                                                         
        # Update the current model's weights
        reshape_to_model(weights_updated, model)

        # Accumulate the loss
        epoch_loss[i] += PDEloss + IVloss
        n_batches += 1

      epoch_loss[i] /= n_batches
      n_batches = 0

      if (np.mod(i, 100)==0):
        print(f"PDE loss, IV loss in {i}th epoch: {PDEloss.numpy():6.4f}, {IVloss.numpy():6.4f}")
      
    return epoch_loss

# %% [markdown]
# ### Train the network

# %%
# Pinn model to be used
model = build_neural_network()

# %%
# Parameters of the problem
data = {'t_bdry': [t0, tfinal],
        'x_bdry': [xleft, xright],
        'u0': u0}

# %%
# Train the learnable optimizer
tasks = 100
cycles = 1 
steps = 50 
K = 1 
N = 2
sigma = 0.1
alpha = 1e-4
wd = 0.0

opt = LearnableOptimizer()
training_loss = opt.train_optimizer(data, model, tasks=tasks, cycles=cycles,
                                    steps=steps, K=K, N=N, sigma=sigma,
                                    alpha=alpha, wd=wd)
# Out:
# Streaming output truncated to the last 5000 lines.
# Accumulated loss over step 45:  0.1801.
#
# Working on optimization step 46 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.1486.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.1755.
#
# Working on optimization step 48 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 48:  0.1656.
#
# Working on optimization step 49 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 49:  0.1666.
#
# Working on optimization step 50 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 50:  0.1425.
#
# Working on task 51 out of 100 tasks:
# Working on optimization step 1 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 1:  0.3555.
#
# Working on optimization step 2 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 2:  0.4407.
#
# Working on optimization step 3 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 3:  0.6607.
#
# Working on optimization step 4 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 4:  0.1991.
#
# Working on optimization step 5 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 5:  0.2093.
#
# Working on optimization step 6 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 6:  0.4077.
#
# Working on optimization step 7 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 7:  0.4638.
#
# Working on optimization step 8 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 8:  0.3211.
#
# Working on optimization step 9 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 9:  0.2469.
#
# Working on optimization step 10 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 10:  0.2339.
#
# Working on optimization step 11 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 11:  0.2101.
#
# Working on optimization step 12 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 12:  0.2315.
#
# Working on optimization step 13 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 13:  0.2270.
#
# Working on optimization step 14 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 14:  0.2216.
#
# Working on optimization step 15 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 15:  0.1882.
#
# Working on optimization step 16 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 16:  0.3372.
#
# Working on optimization step 17 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 17:  0.3102.
#
# Working on optimization step 18 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 18:  0.2712.
#
# Working on optimization step 19 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 19:  0.3331.
#
# Working on optimization step 20 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 20:  0.2935.
#
# Working on optimization step 21 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 21:  0.2004.
#
# Working on optimization step 22 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 22:  0.1967.
#
# Working on optimization step 23 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 23:  0.1731.
#
# Working on optimization step 24 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 24:  0.2145.
#
# Working on optimization step 25 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 25:  0.1987.
#
# Working on optimization step 26 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 26:  0.2430.
#
# Working on optimization step 27 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 27:  0.2458.
#
# Working on optimization step 28 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 28:  0.1751.
#
# Working on optimization step 29 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 29:  0.1554.
#
# Working on optimization step 30 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 30:  0.2063.
#
# Working on optimization step 31 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 31:  0.1745.
#
# Working on optimization step 32 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 32:  0.1556.
#
# Working on optimization step 33 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 33:  0.1473.
#
# Working on optimization step 34 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 34:  0.1410.
#
# Working on optimization step 35 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 35:  0.1390.
#
# Working on optimization step 36 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 36:  0.1373.
#
# Working on optimization step 37 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 37:  0.1527.
#
# Working on optimization step 38 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 38:  0.1514.
#
# Working on optimization step 39 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 39:  0.1451.
#
# Working on optimization step 40 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 40:  0.1429.
#
# Working on optimization step 41 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 41:  0.1444.
#
# Working on optimization step 42 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 42:  0.1385.
#
# Working on optimization step 43 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 43:  0.1371.
#
# Working on optimization step 44 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 44:  0.1415.
#
# Working on optimization step 45 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 45:  0.1467.
#
# Working on optimization step 46 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.1650.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.1537.
#
# Working on optimization step 48 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 48:  0.1491.
#
# Working on optimization step 49 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 49:  0.1463.
#
# Working on optimization step 50 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 50:  0.1704.
#
# Working on task 52 out of 100 tasks:
# Working on optimization step 1 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 1:  0.6125.
#
# Working on optimization step 2 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 2:  1.5262.
#
# Working on optimization step 3 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 3:  1.6648.
#
# Working on optimization step 4 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 4:  0.8523.
#
# Working on optimization step 5 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 5:  0.6912.
#
# Working on optimization step 6 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 6:  0.6898.
#
# Working on optimization step 7 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 7:  0.5878.
#
# Working on optimization step 8 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 8:  0.5306.
#
# Working on optimization step 9 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 9:  0.5108.
#
# Working on optimization step 10 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 10:  0.4892.
#
# Working on optimization step 11 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 11:  0.4833.
#
# Working on optimization step 12 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 12:  0.4702.
#
# Working on optimization step 13 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 13:  0.4758.
#
# Working on optimization step 14 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 14:  0.4887.
#
# Working on optimization step 15 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 15:  0.4785.
#
# Working on optimization step 16 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 16:  0.4474.
#
# Working on optimization step 17 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 17:  0.4349.
#
# Working on optimization step 18 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 18:  0.4352.
#
# Working on optimization step 19 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 19:  0.4369.
#
# Working on optimization step 20 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 20:  0.4278.
#
# Working on optimization step 21 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 21:  0.4171.
#
# Working on optimization step 22 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 22:  0.4151.
#
# Working on optimization step 23 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 23:  0.3924.
#
# Working on optimization step 24 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 24:  0.3788.
#
# Working on optimization step 25 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 25:  0.3787.
#
# Working on optimization step 26 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 26:  0.4131.
#
# Working on optimization step 27 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 27:  0.4477.
#
# Working on optimization step 28 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 28:  0.4572.
#
# Working on optimization step 29 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 29:  0.4819.
#
# Working on optimization step 30 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 30:  0.4490.
#
# Working on optimization step 31 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 31:  0.4357.
#
# Working on optimization step 32 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 32:  0.5042.
#
# Working on optimization step 33 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 33:  0.4478.
#
# Working on optimization step 34 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 34:  0.3633.
#
# Working on optimization step 35 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 35:  0.3528.
#
# Working on optimization step 36 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 36:  0.3668.
#
# Working on optimization step 37 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 37:  0.3621.
#
# Working on optimization step 38 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 38:  0.3527.
#
# Working on optimization step 39 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 39:  0.3464.
#
# Working on optimization step 40 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 40:  0.3518.
#
# Working on optimization step 41 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 41:  0.3525.
#
# Working on optimization step 42 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 42:  0.3259.
#
# Working on optimization step 43 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 43:  0.3120.
#
# Working on optimization step 44 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 44:  0.3055.
#
# Working on optimization step 45 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 45:  0.2903.
#
# Working on optimization step 46 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.3040.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.2982.
#
# Working on optimization step 48 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 48:  0.2783.
#
# Working on optimization step 49 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 49:  0.2763.
#
# Working on optimization step 50 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 50:  0.2568.
#
# Working on task 53 out of 100 tasks:
# Working on optimization step 1 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 1:  0.5851.
#
# Working on optimization step 2 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 2:  0.5568.
#
# Working on optimization step 3 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 3:  0.6240.
#
# Working on optimization step 4 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 4:  0.9139.
#
# Working on optimization step 5 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 5:  0.9670.
#
# Working on optimization step 6 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 6:  0.8161.
#
# Working on optimization step 7 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 7:  0.8800.
#
# Working on optimization step 8 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 8:  0.8823.
#
# Working on optimization step 9 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 9:  0.5519.
#
# Working on optimization step 10 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 10:  0.5724.
#
# Working on optimization step 11 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 11:  0.5986.
#
# Working on optimization step 12 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 12:  0.5914.
#
# Working on optimization step 13 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 13:  0.4636.
#
# Working on optimization step 14 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 14:  0.4455.
#
# Working on optimization step 15 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 15:  0.4394.
#
# Working on optimization step 16 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 16:  0.4306.
#
# Working on optimization step 17 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 17:  0.5920.
#
# Working on optimization step 18 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 18:  0.7137.
#
# Working on optimization step 19 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 19:  0.5131.
#
# Working on optimization step 20 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 20:  0.4000.
#
# Working on optimization step 21 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 21:  0.3887.
#
# Working on optimization step 22 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 22:  0.3790.
#
# Working on optimization step 23 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 23:  0.3848.
#
# Working on optimization step 24 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 24:  0.4875.
#
# Working on optimization step 25 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 25:  0.5158.
#
# Working on optimization step 26 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 26:  0.3575.
#
# Working on optimization step 27 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 27:  0.3291.
#
# Working on optimization step 28 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 28:  0.4941.
#
# Working on optimization step 29 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 29:  0.5800.
#
# Working on optimization step 30 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 30:  0.3893.
#
# Working on optimization step 31 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 31:  0.3263.
#
# Working on optimization step 32 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 32:  0.3458.
#
# Working on optimization step 33 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 33:  0.3144.
#
# Working on optimization step 34 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 34:  0.3792.
#
# Working on optimization step 35 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 35:  0.3763.
#
# Working on optimization step 36 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 36:  0.3328.
#
# Working on optimization step 37 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 37:  0.3070.
#
# Working on optimization step 38 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 38:  0.3097.
#
# Working on optimization step 39 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 39:  0.2985.
#
# Working on optimization step 40 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 40:  0.3002.
#
# Working on optimization step 41 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 41:  0.2730.
#
# Working on optimization step 42 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 42:  0.3289.
#
# Working on optimization step 43 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 43:  0.3005.
#
# Working on optimization step 44 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 44:  0.2655.
#
# Working on optimization step 45 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 45:  0.2669.
#
# Working on optimization step 46 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.2677.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.2850.
#
# Working on optimization step 48 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 48:  0.2755.
#
# Working on optimization step 49 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 49:  0.2678.
#
# Working on optimization step 50 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 50:  0.2539.
#
# Working on task 54 out of 100 tasks:
# Working on optimization step 1 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 1:  0.5872.
#
# Working on optimization step 2 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 2:  0.5360.
#
# Working on optimization step 3 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 3:  0.5207.
#
# Working on optimization step 4 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 4:  0.5749.
#
# Working on optimization step 5 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 5:  0.6049.
#
# Working on optimization step 6 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 6:  0.6070.
#
# Working on optimization step 7 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 7:  0.5737.
#
# Working on optimization step 8 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 8:  0.5208.
#
# Working on optimization step 9 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 9:  0.5268.
#
# Working on optimization step 10 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 10:  0.5543.
#
# Working on optimization step 11 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 11:  0.4768.
#
# Working on optimization step 12 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 12:  0.4744.
#
# Working on optimization step 13 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 13:  0.4532.
#
# Working on optimization step 14 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 14:  0.4443.
#
# Working on optimization step 15 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 15:  0.4277.
#
# Working on optimization step 16 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 16:  0.4180.
#
# Working on optimization step 17 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 17:  0.4079.
#
# Working on optimization step 18 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 18:  0.4145.
#
# Working on optimization step 19 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 19:  0.4521.
#
# Working on optimization step 20 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 20:  0.4384.
#
# Working on optimization step 21 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 21:  0.3876.
#
# Working on optimization step 22 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 22:  0.3665.
#
# Working on optimization step 23 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 23:  0.3652.
#
# Working on optimization step 24 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 24:  0.3680.
#
# Working on optimization step 25 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 25:  0.3704.
#
# Working on optimization step 26 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 26:  0.3718.
#
# Working on optimization step 27 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 27:  0.3630.
#
# Working on optimization step 28 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 28:  0.2982.
#
# Working on optimization step 29 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 29:  0.3103.
#
# Working on optimization step 30 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 30:  0.2630.
#
# Working on optimization step 31 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 31:  0.2436.
#
# Working on optimization step 32 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 32:  0.2746.
#
# Working on optimization step 33 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 33:  0.2733.
#
# Working on optimization step 34 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 34:  0.2859.
#
# Working on optimization step 35 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 35:  0.2408.
#
# Working on optimization step 36 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 36:  0.2926.
#
# Working on optimization step 37 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 37:  0.2719.
#
# Working on optimization step 38 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 38:  0.2502.
#
# Working on optimization step 39 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 39:  0.2391.
#
# Working on optimization step 40 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 40:  0.2132.
#
# Working on optimization step 41 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 41:  0.2081.
#
# Working on optimization step 42 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 42:  0.1965.
#
# Working on optimization step 43 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 43:  0.1987.
#
# Working on optimization step 44 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 44:  0.1921.
#
# Working on optimization step 45 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 45:  0.1846.
#
# Working on optimization step 46 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.1844.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.1872.
#
# Working on optimization step 48 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 48:  0.2418.
#
# Working on optimization step 49 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 49:  0.2190.
#
# Working on optimization step 50 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 50:  0.2426.
#
# Working on task 55 out of 100 tasks:
# Working on optimization step 1 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 1:  0.2458.
#
# Working on optimization step 2 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 2:  0.1976.
#
# Working on optimization step 3 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 3:  0.2662.
#
# Working on optimization step 4 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 4:  0.2431.
#
# Working on optimization step 5 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 5:  0.2059.
#
# Working on optimization step 6 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 6:  0.2060.
#
# Working on optimization step 7 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 7:  0.1769.
#
# Working on optimization step 8 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 8:  0.1976.
#
# Working on optimization step 9 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 9:  0.1926.
#
# Working on optimization step 10 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 10:  0.1932.
#
# Working on optimization step 11 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 11:  0.2925.
#
# Working on optimization step 12 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 12:  0.2721.
#
# Working on optimization step 13 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 13:  0.2451.
#
# Working on optimization step 14 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 14:  0.2210.
#
# Working on optimization step 15 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 15:  0.2010.
#
# Working on optimization step 16 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 16:  0.1641.
#
# Working on optimization step 17 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 17:  0.1580.
#
# Working on optimization step 18 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 18:  0.1542.
#
# Working on optimization step 19 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 19:  0.2245.
#
# Working on optimization step 20 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 20:  0.2342.
#
# Working on optimization step 21 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 21:  0.1696.
#
# Working on optimization step 22 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 22:  0.1641.
#
# Working on optimization step 23 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 23:  0.1559.
#
# Working on optimization step 24 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 24:  0.1507.
#
# Working on optimization step 25 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 25:  0.1621.
#
# Working on optimization step 26 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 26:  0.1780.
#
# Working on optimization step 27 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 27:  0.1659.
#
# Working on optimization step 28 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 28:  0.1497.
#
# Working on optimization step 29 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 29:  0.1554.
#
# Working on optimization step 30 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 30:  0.1637.
#
# Working on optimization step 31 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 31:  0.1761.
#
# Working on optimization step 32 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 32:  0.1601.
#
# Working on optimization step 33 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 33:  0.1593.
#
# Working on optimization step 34 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 34:  0.1571.
#
# Working on optimization step 35 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 35:  0.1483.
#
# Working on optimization step 36 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 36:  0.1384.
#
# Working on optimization step 37 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 37:  0.1375.
#
# Working on optimization step 38 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 38:  0.1569.
#
# Working on optimization step 39 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 39:  0.1646.
#
# Working on optimization step 40 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 40:  0.1546.
#
# Working on optimization step 41 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 41:  0.1367.
#
# Working on optimization step 42 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 42:  0.1315.
#
# Working on optimization step 43 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 43:  0.1309.
#
# Working on optimization step 44 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 44:  0.1331.
#
# Working on optimization step 45 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 45:  0.1326.
#
# Working on optimization step 46 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.1336.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.1393.
#
# Working on optimization step 48 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 48:  0.1450.
#
# Working on optimization step 49 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 49:  0.1403.
#
# Working on optimization step 50 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 50:  0.1404.
#
# Working on task 56 out of 100 tasks:
# Working on optimization step 1 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 1:  0.5944.
#
# Working on optimization step 2 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 2:  0.5575.
#
# Working on optimization step 3 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 3:  0.5962.
#
# Working on optimization step 4 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 4:  0.5835.
#
# Working on optimization step 5 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 5:  0.6977.
#
# Working on optimization step 6 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 6:  0.7847.
#
# Working on optimization step 7 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 7:  0.6848.
#
# Working on optimization step 8 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 8:  0.8026.
#
# Working on optimization step 9 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 9:  0.6348.
#
# Working on optimization step 10 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 10:  0.6490.
#
# Working on optimization step 11 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 11:  0.7181.
#
# Working on optimization step 12 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 12:  0.6208.
#
# Working on optimization step 13 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 13:  0.5108.
#
# Working on optimization step 14 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 14:  0.4991.
#
# Working on optimization step 15 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 15:  0.6163.
#
# Working on optimization step 16 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 16:  0.8128.
#
# Working on optimization step 17 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 17:  0.7927.
#
# Working on optimization step 18 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 18:  0.5489.
#
# Working on optimization step 19 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 19:  0.4961.
#
# Working on optimization step 20 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 20:  0.6476.
#
# Working on optimization step 21 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 21:  0.7825.
#
# Working on optimization step 22 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 22:  0.5931.
#
# Working on optimization step 23 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 23:  0.7129.
#
# Working on optimization step 24 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 24:  0.7208.
#
# Working on optimization step 25 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 25:  0.5922.
#
# Working on optimization step 26 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 26:  0.6803.
#
# Working on optimization step 27 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 27:  0.5833.
#
# Working on optimization step 28 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 28:  0.4929.
#
# Working on optimization step 29 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 29:  0.5027.
#
# Working on optimization step 30 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 30:  0.6303.
#
# Working on optimization step 31 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 31:  0.6613.
#
# Working on optimization step 32 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 32:  0.5083.
#
# Working on optimization step 33 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 33:  0.5225.
#
# Working on optimization step 34 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 34:  0.5557.
#
# Working on optimization step 35 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 35:  0.5874.
#
# Working on optimization step 36 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 36:  0.5425.
#
# Working on optimization step 37 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 37:  0.5078.
#
# Working on optimization step 38 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 38:  0.4689.
#
# Working on optimization step 39 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 39:  0.5027.
#
# Working on optimization step 40 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 40:  0.4758.
#
# Working on optimization step 41 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 41:  0.4482.
#
# Working on optimization step 42 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 42:  0.4548.
#
# Working on optimization step 43 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 43:  0.4715.
#
# Working on optimization step 44 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 44:  0.4697.
#
# Working on optimization step 45 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 45:  0.4915.
#
# Working on optimization step 46 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.4933.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.4725.
#
# Working on optimization step 48 out of 50 steps:
# ...
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.4798.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.4748.
#
# Working on optimization step 48 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 48:  0.4195.
#
# Working on optimization step 49 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 49:  0.4082.
#
# Working on optimization step 50 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 50:  0.4498.
#
# Working on task 69 out of 100 tasks:
# Working on optimization step 1 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 1:  0.6925.
#
# Working on optimization step 2 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 2:  1.6019.
#
# Working on optimization step 3 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 3:  0.7710.
#
# Working on optimization step 4 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 4:  0.5865.
#
# Working on optimization step 5 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 5:  0.6166.
#
# Working on optimization step 6 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 6:  0.6392.
#
# Working on optimization step 7 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 7:  0.5657.
#
# Working on optimization step 8 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 8:  0.6675.
#
# Working on optimization step 9 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 9:  0.6165.
#
# Working on optimization step 10 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 10:  0.7257.
#
# Working on optimization step 11 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 11:  0.7542.
#
# Working on optimization step 12 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 12:  0.5018.
#
# Working on optimization step 13 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 13:  0.4673.
#
# Working on optimization step 14 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 14:  0.5313.
#
# Working on optimization step 15 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 15:  0.4846.
#
# Working on optimization step 16 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 16:  0.5154.
#
# Working on optimization step 17 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 17:  0.4627.
#
# Working on optimization step 18 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 18:  0.4324.
#
# Working on optimization step 19 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 19:  0.4376.
#
# Working on optimization step 20 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 20:  0.4312.
#
# Working on optimization step 21 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 21:  0.3951.
#
# Working on optimization step 22 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 22:  0.4298.
#
# Working on optimization step 23 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 23:  0.4498.
#
# Working on optimization step 24 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 24:  0.3942.
#
# Working on optimization step 25 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 25:  0.3360.
#
# Working on optimization step 26 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 26:  0.3351.
#
# Working on optimization step 27 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 27:  0.3360.
#
# Working on optimization step 28 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 28:  0.3024.
#
# Working on optimization step 29 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 29:  0.2838.
#
# Working on optimization step 30 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 30:  0.3023.
#
# Working on optimization step 31 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 31:  0.3097.
#
# Working on optimization step 32 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 32:  0.2874.
#
# Working on optimization step 33 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 33:  0.2660.
#
# Working on optimization step 34 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 34:  0.3067.
#
# Working on optimization step 35 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 35:  0.2677.
#
# Working on optimization step 36 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 36:  0.2605.
#
# Working on optimization step 37 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 37:  0.2613.
#
# Working on optimization step 38 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 38:  0.2275.
#
# Working on optimization step 39 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 39:  0.2918.
#
# Working on optimization step 40 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 40:  0.2680.
#
# Working on optimization step 41 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 41:  0.2280.
#
# Working on optimization step 42 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 42:  0.2013.
#
# Working on optimization step 43 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 43:  0.2031.
#
# Working on optimization step 44 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 44:  0.2014.
#
# Working on optimization step 45 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 45:  0.1993.
#
# Working on optimization step 46 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 46:  0.2018.
#
# Working on optimization step 47 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 47:  0.2119.
#
# Working on optimization step 48 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 48:  0.1977.
#
# Working on optimization step 49 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 49:  0.1965.
#
# Working on optimization step 50 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 50:  0.1775.
#
# Working on task 70 out of 100 tasks:
# Working on optimization step 1 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 1:  0.8682.
#
# Working on optimization step 2 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 2:  0.7169.
#
# Working on optimization step 3 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 3:  0.5924.
#
# Working on optimization step 4 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 4:  0.8353.
#
# Working on optimization step 5 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 5:  0.6976.
#
# Working on optimization step 6 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 6:  0.5454.
#
# Working on optimization step 7 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 7:  0.6039.
#
# Working on optimization step 8 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 8:  0.7451.
#
# Working on optimization step 9 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 9:  0.8517.
#
# Working on optimization step 10 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 10:  0.7172.
#
# Working on optimization step 11 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 11:  0.5299.
#
# Working on optimization step 12 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 12:  0.5416.
#
# Working on optimization step 13 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 13:  0.6082.
#
# Working on optimization step 14 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 14:  0.5663.
#
# Working on optimization step 15 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 15:  0.5301.
#
# Working on optimization step 16 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 16:  0.6776.
#
# Working on optimization step 17 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 17:  0.5537.
#
# Working on optimization step 18 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 18:  0.4820.
#
# Working on optimization step 19 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 19:  0.4970.
#
# Working on optimization step 20 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 20:  0.5307.
#
# Working on optimization step 21 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 21:  0.4985.
#
# Working on optimization step 22 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 22:  0.4872.
#
# Working on optimization step 23 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 23:  0.4867.
#
# Working on optimization step 24 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 24:  0.4577.
#
# Working on optimization step 25 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 25:  0.4818.
#
# Working on optimization step 26 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 26:  0.5350.
#
# Working on optimization step 27 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 27:  0.5161.
#
# Working on optimization step 28 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 28:  0.5011.
#
# Working on optimization step 29 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 29:  0.6875.
#
# Working on optimization step 30 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 30:  0.8584.
#
# Working on optimization step 31 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 31:  0.6298.
#
# Working on optimization step 32 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 32:  0.5279.
#
# Working on optimization step 33 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 33:  0.6495.
#
# Working on optimization step 34 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 34:  0.7827.
#
# Working on optimization step 35 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 35:  0.9496.
#
# Working on optimization step 36 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 36:  0.7468.
#
# Working on optimization step 37 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 37:  0.4958.
#
# Working on optimization step 38 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 38:  0.5762.
#
# Working on optimization step 39 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 39:  0.5206.
#
# Working on optimization step 40 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# Accumulated loss over step 40:  0.5608.
#
# Working on optimization step 41 out of 50 steps:
# Training model 1 out of 2 models.
# Training model 2 out of 2 models.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-37baeaa083b1> in <module>
#      10
#      11 opt = LearnableOptimizer()
# ---> 12 training_loss = opt.train_optimizer(data, model, tasks=tasks, cycles=cycles,
#      13                                     steps=steps, K=K, N=N, sigma=sigma,
#      14                                     alpha=alpha, wd=wd)
#
# <ipython-input-14-6bc7899636b1> in train_optimizer(self, data, model, N_pde, N_iv, tasks, cycles, steps, K, N, sigma, alpha, wd, clipping, use_adam)
#     280               no_batches = 0
#     281
# --> 282               for (pdes, inits) in ds[task]:
#     283
#     284                 # Train the model for one batch (using the linear advection equation!)
#
# KeyboardInterrupt:

# %%
tasks = training_loss.shape[0]
steps = training_loss.shape[1]

for i in range(tasks):
  plt.plot(np.linspace(1, steps+1, steps), training_loss[i,])
plt.xlabel('Training step')
plt.ylabel('Mean loss')
plt.grid()

# %%
epochs = 1000

# Train PINN using the learnable optimizer
model = build_neural_network()

# Clone model before training to exactly compare optimizers
model_ = build_neural_network()
model_.set_weights(model.get_weights())

# %%
loss = opt.train_model(data, model, epochs, k=2, p=np.pi/4)
# Out:
# PDE loss, IV loss in 0th epoch: 0.0172, 0.5683
# PDE loss, IV loss in 100th epoch: 0.0207, 0.0924
# PDE loss, IV loss in 200th epoch: 0.0231, 0.0670
# PDE loss, IV loss in 300th epoch: 0.0178, 0.0108
# PDE loss, IV loss in 400th epoch: 0.0110, 0.0137
# PDE loss, IV loss in 500th epoch: 0.0074, 0.0090
# PDE loss, IV loss in 600th epoch: 0.0104, 0.0031
# PDE loss, IV loss in 700th epoch: 0.0057, 0.0096
# PDE loss, IV loss in 800th epoch: 0.0046, 0.0132
# PDE loss, IV loss in 900th epoch: 0.0055, 0.0039

# %%
plt.semilogy(range(0, epochs), loss)
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

# %%
# Train PINN using the regular Adam optimizer
opt2 = AdamOptimizer()
loss_ = opt2.train_model(data, model_, epochs, k=2, p=np.pi/4)
# Out:
# PDE loss, IV loss in 0th epoch: 0.0064, 0.4072
# PDE loss, IV loss in 100th epoch: 0.0132, 0.1108
# PDE loss, IV loss in 200th epoch: 0.0096, 0.1349
# PDE loss, IV loss in 300th epoch: 0.0105, 0.1342
# PDE loss, IV loss in 400th epoch: 0.0094, 0.1162
# PDE loss, IV loss in 500th epoch: 0.0104, 0.1021
# PDE loss, IV loss in 600th epoch: 0.0163, 0.0628
# PDE loss, IV loss in 700th epoch: 0.0186, 0.0256
# PDE loss, IV loss in 800th epoch: 0.0186, 0.0823
# PDE loss, IV loss in 900th epoch: 0.0223, 0.0887

# %%
plt.semilogy(range(0, epochs), loss)
plt.semilogy(range(0, epochs), loss_)

plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['Learnable','Adam'])
plt.grid()

fname = 'Comparison_tasks' + str(tasks) + '_cycles' + str(cycles) + '_steps' + str(steps) + \
        'K_' + str(K) + 'N_' + str(N) + 'sigma_' + str(sigma) + '_alpha' + str(alpha) +\
        'wd_' + str(wd) + '.png'
plt.savefig(fname)

# %% [markdown]
# ### Visualize results

# %%
# Grid where to evaluate the model
l, m = 100, 200
t = np.linspace(t0, tfinal, l)
x = np.linspace(xleft, xright, m)
T, X = np.meshgrid(t, x, indexing='ij')

u = model([np.expand_dims(T.flatten(), axis=1), 
           np.expand_dims(X.flatten(), axis=1)])
u = np.reshape(u, (l, m))


u_ = model_([np.expand_dims(T.flatten(), axis=1), 
           np.expand_dims(X.flatten(), axis=1)])
u_ = np.reshape(u_, (l, m))

# %%
from scipy.integrate import odeint
from scipy.fftpack import diff as psdiff

L = xright - xleft
xx = np.linspace(xleft, xright, m)
tt = np.linspace(t0, tfinal, l*20) 

# Numerical reference solution for the KdV equation
def kdv(u, t, L):
  ux = psdiff(u, period=L)
  uxxx = psdiff(u, period=L, order=3)
  ut = -u*ux - 0.0025*uxxx
  return ut

def solve_kdv(u0, t, L):
  sol = odeint(kdv, u0, t, args=(L,))
  return sol

ureference = solve_kdv(u0(xx, k=2, p=np.pi/4), tt, L)
ureference = ureference[::20,]

# %%
plt.figure(figsize=(16,5))

plt.subplot(131)
plt.contourf(X, T, u, 100, cmap=plt.cm.jet)
plt.title('Neural network solution')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()

plt.subplot(132)
plt.contourf(X, T, ureference, 100, cmap=plt.cm.jet)
plt.title('Numerical reference solution')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()

plt.subplot(133)
plt.contourf(X, T, u-ureference, 100, cmap=plt.cm.jet)
plt.title('Error')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()

plt.savefig('Learnable.png')

# %%
plt.figure(figsize=(16,5))

plt.subplot(131)
plt.contourf(X, T, u_, 100, cmap=plt.cm.jet)
plt.title('Neural network solution')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()

plt.subplot(132)
plt.contourf(X, T, ureference, 100, cmap=plt.cm.jet)
plt.title('Numerical reference solution')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()

plt.subplot(133)
plt.contourf(X, T, u_-ureference, 100, cmap=plt.cm.jet)
plt.title('Error')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()

plt.savefig('Adam.png')

# %%
# Save the models
opt.optimizer.save('Optimizer.h5')
model.save('Learnable.h5')
model_.save('Adam.h5')
np.save('loss.npy', loss)
np.save('loss_.npy', loss_)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ### Produce an animation

# %%
# filenames = []
# for i in range(l):
#   plt.figure(figsize=(10,5))
#   plt.subplot(111)
#   plt.plot(X[i,], u[i,])
#   plt.title('Neural network solution at time {: 4.2f}'.format(T[i,0]))
#   plt.xlabel('u(t)')
#   plt.ylabel('x')

#   filename = f'{i}.png'
#   filenames.append(filename)
#   plt.savefig(filename)
#   plt.close()

# with imageio.get_writer('LinearAdvection.gif', mode='I') as writer:
#     for filename in filenames:
#         image = imageio.imread(filename)
#         writer.append_data(image)

# for filename in set(filenames):
#   os.remove(filename)

# files.download('LinearAdvection.gif')
